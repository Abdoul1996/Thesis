# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
data = pd.read_csv('/Users/abdoulabdillahi/Desktop/Thesis/Bio_project/200_samples_with_encoded.csv')

# %%
# Show the 5 rows of the dataset
data.head()
# Out:
#   Run accession  Ciprofloxacin_NS  \
# 0    ERR4035837                 1
# 1    ERR4034242                 1
# 2    ERR4034731                 1
# 3    ERR4036152                 0
# 4    ERR4036469                 0
#
#                                               gene_0  \
# 0  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
# 1  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
# 2  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
# 3  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
# 4  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
#
#                                               gene_1  \
# 0  [nan nan nan nan nan nan nan nan nan nan nan n...
# 1  [nan nan nan nan nan nan nan nan nan nan nan n...
# 2  [nan nan nan nan nan nan nan nan nan nan nan n...
# 3  [nan nan nan nan nan nan nan nan nan nan nan n...
# 4  [nan nan nan nan nan nan nan nan nan nan nan n...
#
#                                               gene_2  \
# ...

# %%
data.shape
# Out:
# (154, 15631)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Columns: 15631 entries, Run accession to gene_15628
# dtypes: int64(1), object(15630)
# memory usage: 18.4+ MB

# %%
# print(data.shape)
# print(data.columns[:10])  # Preview column names
print(data.head(2).T)     # Transpose to see row structure vertically
# Out:
#                                                                   0  \
# Run accession                                            ERR4035837
# Ciprofloxacin_NS                                                  1
# gene_0            ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
# gene_1            [nan nan nan nan nan nan nan nan nan nan nan n...
# gene_2            [nan nan nan nan nan nan nan nan nan nan nan n...
# ...                                                             ...
# gene_15624        ['-' '-' '-' '-' '-' '-' 'c' 't' 'g' 't' 'a' '...
# gene_15625        ['a' 't' 'a' 't' 'c' 'c' 'c' 'a' 'g' 'a' 't' '...
# gene_15626        [nan nan nan nan nan nan nan nan nan nan nan n...
# gene_15627        [nan nan nan nan nan nan nan nan nan nan nan n...
# gene_15628        [nan nan nan nan nan nan nan nan nan nan nan n...
#
#                                                                   1
# Run accession                                            ERR4034242
# ...

# %%
data.iloc[ :,:10].head()  # First 10 columns
# Out:
#   Run accession  Ciprofloxacin_NS  \
# 0    ERR4035837                 1
# 1    ERR4034242                 1
# 2    ERR4034731                 1
# 3    ERR4036152                 0
# 4    ERR4036469                 0
#
#                                               gene_0  \
# 0  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
# 1  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
# 2  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
# 3  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
# 4  ['a' 't' 'g' 't' 'c' 't' 'a' 't' 'a' 'c' 'a' '...
#
#                                               gene_1  \
# 0  [nan nan nan nan nan nan nan nan nan nan nan n...
# 1  [nan nan nan nan nan nan nan nan nan nan nan n...
# 2  [nan nan nan nan nan nan nan nan nan nan nan n...
# 3  [nan nan nan nan nan nan nan nan nan nan nan n...
# 4  [nan nan nan nan nan nan nan nan nan nan nan n...
#
#                                               gene_2  \
# ...

# %%
data['gene_0'].value_counts().head(10)
# Out:
# gene_0
# ...

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']
categorical_features = [feature for feature in data.columns if data[feature].dtype == 'O']

# %%
# proportion of count data on categorical columns
for col in categorical_features[:3]:
    print(data[col].value_counts(normalize=True) * 100)
    print('---------------------------')
# Out:
# Run accession
# ERR4035837    0.649351
# ERR4035241    0.649351
# ERR4034645    0.649351
# ERR4034354    0.649351
# ERR4037229    0.649351
#                 ...
# ERR4036861    0.649351
# ERR4036248    0.649351
# ERR4036849    0.649351
# ERR4036637    0.649351
# ERR4037261    0.649351
# Name: proportion, Length: 154, dtype: float64
# ---------------------------
# gene_0
# ...
